# %%
from pyod.models.abod import ABOD
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

import os
import pickle

from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt 
# %matplotlib inline

import sys
sys.path.append('..')
sys.path.append('../..')

from src.utils import train_test_anomaly, raw_thresholds

# %%
file_path = '../../datasets/Dodgers/101-freeway-traffic.test.out'

columns = ['value', 'anomaly']

df = pd.read_csv(file_path, names=columns, header=None)

# %%
df = df[df['value'] >= 0]
df['anomaly'].value_counts()
# Out:
# anomaly
# 0    44788
# 1     2709
# Name: count, dtype: int64

# %%
# Preparing Train and Test Dataset

X_train, X_test = train_test_split(df, test_size=0.3, shuffle=False)
train_x = X_train[['value']].values.reshape(-1, 1)
train_y = X_train[['anomaly']].values.ravel()
test_data = X_test[['value']]
gtruth = X_test[['anomaly']]

# %%
model = ABOD()
model.fit(train_x)
# Out:
# /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3715: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 model = ABOD()
# ----> 2 model.fit(train_x)
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/pyod/models/abod.py:172, in ABOD.fit(self, X, y)
#     169 self.decision_scores_ = np.zeros([self.n_train_, 1])
#     171 if self.method == 'fast':
# --> 172     self._fit_fast()
#     173 elif self.method == 'default':
#     174     self._fit_default()
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/pyod/models/abod.py:223, in ABOD._fit_fast(self)
#     221     curr_pt = self.X_train_[i, :]
#     222     X_ind = ind_arr[i, :]
# --> 223     self.decision_scores_[i, 0] = _calculate_wocs(curr_pt,
#     224                                                   self.X_train_,
#     225                                                   X_ind)
#     226 return self
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/pyod/models/abod.py:88, in _calculate_wocs(curr_pt, X, X_ind)
#      86         continue
#      87     # add the weighted cosine to the list
# ---> 88     wcos_list.append(_wcos(curr_pt, a, b))
#      89 return np.var(wcos_list)
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/numba/core/dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/numba/core/dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# No implementation of function Function(<function dot at 0x7d4900191af0>) found for signature:
#
#  >>> dot(array(int64, 1d, C), array(int64, 1d, C))
#
# There are 4 candidate implementations:
#   - Of which 2 did not match due to:
#   Overload in function 'dot_2': File: numba/np/linalg.py: Line 525.
#     With argument(s): '(array(int64, 1d, C), array(int64, 1d, C))':
#    Rejected as the implementation raised a specific error:
#      LoweringError: Failed in nopython mode pipeline (step: native lowering)
#    unsupported dtype for <BLAS function>()
#
#    File "../../../../../../anaconda3/envs/venv/lib/python3.9/site-packages/numba/np/linalg.py", line 582:
#                def _dot2_codegen(context, builder, sig, args):
#                    <source elided>
#
#            return lambda left, right: _impl(left, right)
#            ^
#
#    During: lowering "$8call_function.3 = call $2load_deref.0(left, right, func=$2load_deref.0, args=[Var(left, linalg.py:582), Var(right, linalg.py:582)], kws=(), vararg=None, varkwarg=None, target=None)" at /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/numba/np/linalg.py (582)
#   raised from /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/numba/core/errors.py:874
#   - Of which 2 did not match due to:
#   Overload in function 'dot_3': File: numba/np/linalg.py: Line 784.
#     With argument(s): '(array(int64, 1d, C), array(int64, 1d, C))':
#    Rejected as the implementation raised a specific error:
#      TypingError: missing a required argument: 'out'
#   raised from /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/numba/core/typing/templates.py:784
#
# During: resolving callee type: Function(<function dot at 0x7d4900191af0>)
# During: typing of call at /home/rojan/anaconda3/envs/venv/lib/python3.9/site-packages/pyod/models/abod.py (51)
#
#
# File "../../../../../../anaconda3/envs/venv/lib/python3.9/site-packages/pyod/models/abod.py", line 51:
# def _wcos(curr_pt, a, b):  # pragma: no cover
#     <source elided>
#     # wcos = (<a_curr, b_curr>/((|a_curr|*|b_curr|)^2)
#     wcos = np.dot(a_curr, b_curr) / (
#     ^
