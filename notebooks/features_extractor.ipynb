# %%
import sys
import pickle
import pandas as pd
import numpy as np

sys.path.append('..')
sys.path.append('../..')

from src.Components.data_processing import data_process

# %%
filepath = '../datasets/ECG/MBA_ECG14046_data_0.out'
column_name = ['value', 'anomaly']
df = pd.read_csv(filepath, header=None, names=column_name).dropna()
df = df.iloc[140000:160100]
data_np = df.to_numpy()

name = filepath.split('/')[-1]
min_length = 50000
max_length = 100000


data = data_np[min_length:max_length,0].astype(float)
label = data_np[min_length:max_length,1].astype(int)

# %%
df.shape
# Out:
# (20100, 2)

# %%
from sktime.transformations.panel.tsfresh import TSFreshFeatureExtractor

fe = TSFreshFeatureExtractor(default_fc_parameters="minimal", show_warnings=False, n_jobs=-1)

# %%
windowed_data = data_process(df, window_size=100)
windowed_data.shape
# Out:
# (20000, 100)

# %%
feature_list = []

for i, val in enumerate(windowed_data):
    feature_list.append(fe.fit_transform(val))
    print(i)
# Out:
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 444.08it/s]
# 0
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 513.94it/s]
# 1
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 612.04it/s]
# 2
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 934.56it/s]
# 3
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 543.73it/s]
# 4
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 375.30it/s]
# 5
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 544.93it/s]
# 6
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 279.75it/s]
# 7
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 650.99it/s]
# 8
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 717.22it/s]
# 9
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 433.83it/s]
# 10
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 599.27it/s]
# 11
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 107.39it/s]
# 12
# ...

# %%
with open(f'../data/features_ecg14046_0_140k_160k.pkl', 'wb') as file:
    pickle.dump(feature_list, file)

# %%
len(feature_list)
# Out:
# 20100

# %%
sliced_window = windowed_data[0:10]
sliced_df = df.iloc[0:110]

# %%
sliced_window_df = data_process(sliced_df, window_size=100)

# %%
sliced_window_df.shape
# Out:
# (10, 100)

# %%
sliced_window.shape
# Out:
# (10, 100)

# %%
np.array_equal(sliced_window, sliced_window_df)
# Out:
# True

# %%
with open('../data/features_ecg14046_0_50k_80k.pkl', 'rb') as file:

    ecg_50_80 = pickle.load(file)

with open('../data/features_ecg14046_0_80k_120k.pkl', 'rb') as file:

    ecg_80_120 = pickle.load(file)

with open('../data/features_ecg14046_0_119.8k_140k.pkl', 'rb') as file:

    ecg_19_140 = pickle.load(file)

with open('../data/features_ecg14046_test_35k_20k.pkl', 'rb') as file:

    ecg_35_50 = pickle.load(file)

# %%
print(len(ecg_35_50), len(ecg_50_80), len(ecg_80_120), len(ecg_19_140))
# Out:
# 14900 29900 39900 20100

# %%
first_missing = df.iloc[49900:50100]
second_missing = df.iloc[79900:80100]
third_missing = df.iloc[119900:120100]
forth_missing = df.iloc[139900:140100]

# %%
first_missing_wdw = data_process(first_missing, window_size=100)
second_missing_wdw = data_process(second_missing, window_size=100)
third_missing_wdw = data_process(third_missing, window_size=100)
forth_missing_wdw = data_process(forth_missing, window_size=100)

# %%
first_missing_feat_list = []

for i, val in enumerate(first_missing_wdw):

    first_missing_feat_list.append(fe.fit_transform(val))
    print(i+1)
# Out:
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 314.13it/s]
# 1
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 393.28it/s]
# 2
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 339.04it/s]
# 3
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 289.50it/s]
# 4
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 509.70it/s]
# 5
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 543.66it/s]
# 6
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 310.21it/s]
# 7
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 542.46it/s]
# 8
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 290.69it/s]
# 9
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 343.29it/s]
# 10
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 403.22it/s]
# 11
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 423.28it/s]
# 12
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 311.15it/s]
# 13
# ...

# %%
second_missing_feat_list = []

for i, val in enumerate(second_missing_wdw):

    second_missing_feat_list.append(fe.fit_transform(val))
    print(i+1)
# Out:
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 279.42it/s]
# 1
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 259.47it/s]
# 2
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 614.01it/s]
# 3
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 1648.06it/s]
# 4
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 307.14it/s]
# 5
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 278.86it/s]
# 6
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 454.77it/s]
# 7
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 405.95it/s]
# 8
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 129.35it/s]
# 9
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 293.97it/s]
# 10
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 306.35it/s]
# 11
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 519.61it/s]
# 12
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 655.56it/s]
# 13
# ...

# %%
forth_missing_feat_list = []

for i, val in enumerate(forth_missing_wdw):

    forth_missing_feat_list.append(fe.fit_transform(val))
    print(i+1)
# Out:
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 369.74it/s]
# 1
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 345.49it/s]
# 2
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 328.94it/s]
# 3
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 354.67it/s]
# 4
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 682.67it/s]
# 5
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 384.23it/s]
# 6
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 364.09it/s]
# 7
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 333.41it/s]
# 8
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 396.03it/s]
# 9
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 536.97it/s]
# 10
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 369.15it/s]
# 11
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 595.36it/s]
# 12
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 544.57it/s]
# 13
# ...

# %%
combined_list = ecg_35_50 + first_missing_feat_list + ecg_50_80 + second_missing_feat_list + ecg_80_120 + ecg_19_140[100:] + forth_missing_feat_list

# %%
type(combined_list)
# Out:
# list

# %%
slice_combined_list = combined_list[44100:44110]

# %%
slice_combined_list[0]
# Out:
#    var_0__sum_values  var_0__median  var_0__mean  var_0__length  \
# 0              -4.16         -0.075      -0.0416          100.0
#
#    var_0__standard_deviation  var_0__variance  var_0__root_mean_square  \
# 0                   0.448077         0.200773                 0.450004
#
#    var_0__maximum  var_0__absolute_maximum  var_0__minimum
# 0            2.29                     2.29           -0.76

# %%
sliced_test_df = df.iloc[79100:79210]
window = data_process(sliced_test_df, window_size=100)

# %%
window.shape
# Out:
# (10, 100)

# %%
tester_list = []

for val in window:
    tester_list.append(fe.fit_transform(val))
# Out:
# ...
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 429.83it/s]

# %%
for df1, df2 in zip(tester_list, slice_combined_list):
    print(df1.equals(df2))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
with open(f'../data/ecg14046_0_140k_160k.pkl', 'wb') as file:
    pickle.dump(combined_list, file)
